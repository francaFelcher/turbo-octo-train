# %%
import pandas as pd

# %%
df_exams = pd.read_csv("StudentsPerformance.csv")

# %% [markdown]
# # 1. Selecting 1 Column

# %% [markdown]
# #### SYNTAX 1

# %%
# preferred way
df_exams["gender"]
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams["gender"])
# Out:
# pandas.core.series.Series

# %%
df_exams["gender"].index
df_exams["gender"].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
df_exams["math score"]
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %% [markdown]
# #### SYNTAX 2

# %%
# not so preferred way
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
# df_exams.math score  DOES NOT WORK

# %% [markdown]
# # 2. Selecting 2 or more Columns

# %%
df_exams[["gender", "math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_exams[["gender", "math score"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams[["gender", "math score", "reading score", "writing score"]]
# Out:
#      gender  math score  reading score  writing score
# 0    female          72             72             74
# 1    female          69             90             88
# 2    female          90             95             93
# 3      male          47             57             44
# 4      male          76             78             75
# ..      ...         ...            ...            ...
# 995  female          88             99             95
# 996    male          62             55             55
# 997  female          59             71             65
# 998  female          68             78             77
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %% [markdown]
# # 3. Add new Column

# %% [markdown]
# #### ADDING A NEW COLUMN WITH A SCALAR VALUE

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df_exams["language score"] = 70

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# 2                70
# 3                70
# 4                70
# ..              ...
# 995              70
# 996              70
# 997              70
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %% [markdown]
# #### ADDING A NEW COLUMN WITH AN ARRAY

# %%
import numpy as np

# %%
language_score = np.arange(0, 1000)

# %%
len(language_score)
# Out:
# 1000

# %%
df_exams["language score"] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
len(np.random.randint(1, 100, size=1000))
# Out:
# 1000

# %%
int_language_score = np.random.randint(1, 101, size=1000)

# %%
max(int_language_score)
# Out:
# np.int32(100)

# %%
df_exams["language score"] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                13
# 1                12
# 2                53
# 3                99
# 4                 4
# ..              ...
# 995              85
# 996              38
# 997              96
# 998              13
# 999              51
#
# [1000 rows x 9 columns]

# %% [markdown]
# RANDOM FLOAT NUMBERS

# %%
np.random.uniform(1, 100, size = 10).round(2)
# Out:
# array([ 8.53, 30.85, 72.61, 31.59, 53.08, 45.55, 69.7 , 81.8 , 24.15,
#         7.14])

# %% [markdown]
# ### ADDING A NEW COLUMN WITH assign() AND insert()

# %% [markdown]
# #### assign()
# When to use?
# - add multiples columns in a single line of code
# - overwrite the values of an existing column (best practice)

# %%
score1 = np.random.randint(1, 101, size=1000)
score2 = np.random.randint(1, 101, size=1000)

# %%
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))

# %%
series1
# Out:
# 0      99
# 1      15
# 2      18
# 3       3
# 4       7
#        ..
# 995    75
# 996    40
# 997    96
# 998     1
# 999    85
# Length: 1000, dtype: int32

# %%
series2
# Out:
# 0      49
# 1      96
# 2      58
# 3      98
# 4      22
#        ..
# 995    75
# 996    74
# 997    61
# 998    37
# 999    58
# Length: 1000, dtype: int32

# %%
df_exams = df_exams.assign(score1 = series1, score2 = series2)

# %% [markdown]
# #### insert()
# Insert a new column at a specific position or index

# %%
df_exams.insert(1, "test", series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    99        group B           bachelor's degree      standard
# 1    female    15        group C                some college      standard
# 2    female    18        group B             master's degree      standard
# 3      male     3        group A          associate's degree  free/reduced
# 4      male     7        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    75        group E             master's degree      standard
# 996    male    40        group C                 high school  free/reduced
# 997  female    96        group C                 high school  free/reduced
# 998  female     1        group D                some college      standard
# 999  female    85        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                13      13      70
# 1                12      66      23
# 2                53      36      89
# 3                99      53      65
# 4                 4      51      50
# ..              ...     ...     ...
# 995              85      76      72
# 996              38      29      18
# 997              96      53      30
# 998              13      63      47
# 999              51      25       6
#
# [1000 rows x 12 columns]
